# %% [markdown]
# # full_evaluator.py — Notebook wrapper
# This notebook provides two simple ways to run the existing `full_evaluator.py` script:
# - Use the `%run` IPython magic to execute the script (behaves like running `python full_evaluator.py`).
# - Import the module and call `evaluate()` directly from Python.
#
# Place this notebook in the same folder as the original script and run the cells below.

# %%
# Execute the script (equivalent to running `python full_evaluator.py --docs 5`)
# %run full_evaluator.py --docs 5

# %%
# Alternatively, import the module and call evaluate() directly
import importlib
import full_evaluator
importlib.reload(full_evaluator)
# Run with a limit to avoid long runs while testing
full_evaluator.evaluate(max_docs=5)
